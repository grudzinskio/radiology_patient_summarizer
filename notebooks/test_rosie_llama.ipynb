# %% [markdown]
# # Test for running Rosie's Llama Model

# %%
from pathlib import Path
import sys

# Add repo root so `backend` is importable when running from notebooks/
repo_root = Path.cwd().parent
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

# %%
# Doesn't work for me - Alec

# from backend.llm_clients import RosieLlamaClient

# llama_model = RosieLlamaClient()
# llama_model.generate(
#     [
#         {"role": "user", "content": "Hello, how are you?"}
#     ]
# )

# %%
from backend.app.utils.clients.llm_clients import OpenAIClient


openai_model = OpenAIClient()
openai_model.generate(
    [
        {"role": "user", "content": "Hello, how are you?"}
    ]
)
# Out:
# "I'm doing well — thanks for asking! How can I help you today?"
